# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("edotfs/dht11-temperature-and-humidity-sensor-1-day")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.6), please consider upgrading to the latest version (0.3.11).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/edotfs/dht11-temperature-and-humidity-sensor-1-day?dataset_version_number=1...
# 100%|█████████████████████████████████████████████████████████████████████████████████| 3.90k/3.90k [00:00<00:00, 2.28MB/s]
# Extracting files...
# Path to dataset files: /Users/apurbakoirala/.cache/kagglehub/datasets/edotfs/dht11-temperature-and-humidity-sensor-1-day/versions/1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
import joblib

# %%
df = pd.read_csv('./1/log_temp.csv')

# %%
df.head()
# Out:
#    3/14/19  19:33:07  T=22.0  H=20.0
# 0  3/14/19  19:38:10  T=22.0  H=20.0
# 1  3/14/19  19:43:11  T=22.0  H=26.0
# 2  3/14/19  19:48:14  T=22.0  H=26.0
# 3  3/14/19  19:53:15  T=22.0  H=20.0
# 4  3/14/19  19:58:15  T=22.0  H=23.0

# %%
df.isnull().sum()
# Out:
# 3/14/19      0
# 19:33:07     0
# T=22.0       0
# H=20.0      16
# dtype: int64

# %%
numeric_df = df[['Temperature', 'Humidity']]

# Apply KNN Imputer
imputer = KNNImputer(n_neighbors=3)
imputed_values = imputer.fit_transform(numeric_df)

# Put imputed values back into the DataFrame
df[['Temperature', 'Humidity']] = imputed_values

# %%
df.head()
# Out:
#             Timestamp  Temperature  Humidity
# 0 2019-03-14 19:38:10         22.0      20.0
# 1 2019-03-14 19:43:11         22.0      26.0
# 2 2019-03-14 19:48:14         22.0      26.0
# 3 2019-03-14 19:53:15         22.0      20.0
# 4 2019-03-14 19:58:15         22.0      23.0

# %%
import matplotlib.pyplot as plt

plt.plot(df['Humidity'], label='Humidity (imputed)')
plt.legend()
plt.show()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
X = df[['Temperature', 'Humidity']]

iso_forest = IsolationForest(contamination=0.05, random_state=42)

df['anomaly'] = iso_forest.fit_predict(X)

# %%
df['anomaly'].value_counts()
# Out:
# anomaly
#  1    318
# -1     17
# Name: count, dtype: int64

# %%
normal = df[df['anomaly'] == 1]
anomalies = df[df['anomaly'] == -1]

plt.figure(figsize=(10, 6))
plt.scatter(normal['Temperature'], normal['Humidity'], c='blue', label='Normal')
plt.scatter(anomalies['Temperature'], anomalies['Humidity'], c='red', label='Anomaly')
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.title('Anomaly Detection')
plt.legend()
plt.grid(True)
plt.show()

# %%
lof = LocalOutlierFactor(n_neighbors=20, contamination=0.05)

df['lof_anomaly'] = lof.fit_predict(X)

# %%
df['lof_anomaly'].value_counts()
# Out:
# lof_anomaly
#  1    327
# -1      8
# Name: count, dtype: int64

# %%
normal = df[df['lof_anomaly'] == 1]
anomalies = df[df['lof_anomaly'] == -1]

plt.figure(figsize=(10, 6))
plt.scatter(normal['Temperature'], normal['Humidity'], c='green', label='Normal')
plt.scatter(anomalies['Temperature'], anomalies['Humidity'], c='orange', label='Anomaly')
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.title('LOF Anomaly Detection')
plt.legend()
plt.grid(True)
plt.show()

# %%
joblib.dump(iso_forest, 'iso_forest.pkl')
# Out:
# ['iso_forest.pkl']
